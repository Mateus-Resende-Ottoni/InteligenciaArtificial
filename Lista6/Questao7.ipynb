# %% [markdown]
# # Imports

# %%
import pandas as pd
from apyori import apriori

# %% [markdown]
# # Montagem da base de dados

# %% [markdown]
# ## Leitura da tabela

# %%
dados_base = pd.read_csv('Data/MercadoSim.csv', sep=';',encoding='cp1252', header=None)
# Mudança das colunas para refletir o nome do produto
produtos = ['Leite', 'Cafe', 'Cerveja', 'Pao', 'Manteiga', 'Arroz', 'Feijao']
dados_base.columns = produtos
#
dados_base
# Out:
#    Leite  Cafe  Cerveja  Pao  Manteiga  Arroz  Feijao
# 0    NaN  Cafe      NaN  Pao  Manteiga    NaN     NaN
# 1  Leite   NaN  Cerveja  Pao  Manteiga    NaN     NaN
# 2    NaN  Cafe      NaN  Pao  Manteiga    NaN     NaN
# 3  Leite  Cafe      NaN  Pao  Manteiga    NaN     NaN
# 4    NaN   NaN  Cerveja  NaN       NaN    NaN     NaN
# 5    NaN   NaN      NaN  NaN  Manteiga    NaN     NaN
# 6    NaN   NaN      NaN  Pao       NaN    NaN     NaN
# 7    NaN   NaN      NaN  NaN       NaN    NaN  Feijao
# 8    NaN   NaN      NaN  NaN       NaN  Arroz  Feijao
# 9    NaN   NaN      NaN  NaN       NaN  Arroz     NaN

# %%
# Dimensões da tabela de dados
dados_base.shape
# Out:
# (10, 7)

# %%
print(dados_base['Leite'][0])
print(type(dados_base['Leite'][0]))
print(dados_base['Leite'][1])
print(type(dados_base['Leite'][1]))
# Out:
# nan
# <class 'float'>
# Leite
# <class 'str'>

# %% [markdown]
# ## Criação das colunas de falta de presença

# %%
# Para cada coluna da tabela, criar uma nova que é o oposto,
#  isso é, tem valor sempre que o cliente não levou o produto

# Criação de uma cópia dos dados
dados_opostos = dados_base.copy()
# Mudar nome das colunas
list_new_columns = []
for coluna in dados_opostos.columns:
    novo_nome = "n" + coluna
    list_new_columns.append(novo_nome)
dados_opostos.columns = list_new_columns
#print(dados_opostos)

# Inverter dados
for coluna in dados_opostos.columns:
    for instancia in dados_opostos.index:
        if str(dados_opostos[coluna][instancia]) != 'nan':
            dados_opostos.loc[instancia, coluna] = 'nan'
        else:
            dados_opostos.loc[instancia, coluna] = coluna
#print(dados_opostos)

# Juntar tabelas
dados_base = pd.concat([dados_base, dados_opostos], axis=1)
#print(dados_base)

# %% [markdown]
# ## Transformação em conjunto de listas

# %%
# O método do algoritmo apriori necessita de listas como input
transacoes = []
for i in range(len(dados_base)):
  transacoes.append([str(dados_base.values[i, j]) for j in range(dados_base.shape[1])])
#
transacoes
# Out:
# [['nan',
#   'Cafe',
#   'nan',
#   'Pao',
#   'Manteiga',
#   'nan',
#   'nan',
#   'nLeite',
#   'nan',
#   'nCerveja',
#   'nan',
#   'nan',
#   'nArroz',
#   'nFeijao'],
#  ['Leite',
#   'nan',
#   'Cerveja',
#   'Pao',
#   'Manteiga',
#   'nan',
#   'nan',
#   'nan',
#   'nCafe',
#   'nan',
#   'nan',
#   'nan',
#   'nArroz',
#   'nFeijao'],
#  ['nan',
#   'Cafe',
#   'nan',
#   'Pao',
#   'Manteiga',
#   'nan',
#   'nan',
#   'nLeite',
#   'nan',
#   'nCerveja',
#   'nan',
#   'nan',
#   'nArroz',
#   'nFeijao'],
#  ['Leite',
#   'Cafe',
#   'nan',
#   'Pao',
#   'Manteiga',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nCerveja',
#   'nan',
#   'nan',
#   'nArroz',
#   'nFeijao'],
#  ['nan',
#   'nan',
#   'Cerveja',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nLeite',
#   'nCafe',
#   'nan',
#   'nPao',
#   'nManteiga',
#   'nArroz',
#   'nFeijao'],
#  ['nan',
#   'nan',
#   'nan',
#   'nan',
#   'Manteiga',
#   'nan',
#   'nan',
#   'nLeite',
#   'nCafe',
#   'nCerveja',
#   'nPao',
#   'nan',
#   'nArroz',
#   'nFeijao'],
#  ['nan',
#   'nan',
#   'nan',
#   'Pao',
#   'nan',
#   'nan',
#   'nan',
#   'nLeite',
#   'nCafe',
#   'nCerveja',
#   'nan',
#   'nManteiga',
#   'nArroz',
#   'nFeijao'],
#  ['nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'Feijao',
#   'nLeite',
#   'nCafe',
#   'nCerveja',
#   'nPao',
#   'nManteiga',
#   'nArroz',
#   'nan'],
#  ['nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'Arroz',
#   'Feijao',
#   'nLeite',
#   'nCafe',
#   'nCerveja',
#   'nPao',
#   'nManteiga',
#   'nan',
#   'nan'],
#  ['nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'Arroz',
#   'nan',
#   'nLeite',
#   'nCafe',
#   'nCerveja',
#   'nPao',
#   'nManteiga',
#   'nan',
#   'nFeijao']]

# %%
type(transacoes)
# Out:
# list

# %% [markdown]
# # Chamada do algoritmo

# %% [markdown]
# ## Parâmetros

# %%
suporte_min = 0.3   # Suporte mínimo dos datasets
confianca_min = 0.8 # Confiança mínima das regras

# %% [markdown]
# ## Algoritmo

# %%
regras = apriori(transactions= transacoes, min_support= suporte_min, min_confidence= confianca_min)
saida = list(regras)
print(len(saida))
print(saida)

# Formato base de cada item em 'saida'
# item[0] = itemset
# item[1] = suporte
# item[2] = regras possíveis
#   regra[0] = antecedente
#   regra[1] = consequente
#   regra[2] = confiança
#   regra[3] = lift
# Out:
# 259
# [RelationRecord(items=frozenset({'nArroz'}), support=0.8, ordered_statistics=[OrderedStatistic(items_base=frozenset(), items_add=frozenset({'nArroz'}), confidence=0.8, lift=1.0)]), RelationRecord(items=frozenset({'nCerveja'}), support=0.8, ordered_statistics=[OrderedStatistic(items_base=frozenset(), items_add=frozenset({'nCerveja'}), confidence=0.8, lift=1.0)]), RelationRecord(items=frozenset({'nFeijao'}), support=0.8, ordered_statistics=[OrderedStatistic(items_base=frozenset(), items_add=frozenset({'nFeijao'}), confidence=0.8, lift=1.0)]), RelationRecord(items=frozenset({'nLeite'}), support=0.8, ordered_statistics=[OrderedStatistic(items_base=frozenset(), items_add=frozenset({'nLeite'}), confidence=0.8, lift=1.0)]), RelationRecord(items=frozenset({'nan'}), support=1.0, ordered_statistics=[OrderedStatistic(items_base=frozenset(), items_add=frozenset({'nan'}), confidence=1.0, lift=1.0)]), RelationRecord(items=frozenset({'Manteiga', 'Cafe'}), support=0.3, ordered_statistics=[OrderedStatistic(items_base=frozenset({'Cafe'}), items_add=frozenset({'Manteiga'}), confidence=1.0, lift=2.0)]), RelationRecord(items=frozenset({'Pao', 'Cafe'}), support=0.3, ordered_statistics=[OrderedStatistic(items_base=frozenset({'Cafe'}), items_add=frozenset({'Pao'}), confidence=1.0, lift=2.0)]), RelationRecord(items=frozenset({'nArroz', 'Cafe'}), support=0.3, ordered_statistics=[OrderedStatistic(items_base=frozenset({'Cafe'}), items_add=frozenset({'nArroz'}), confidence=1.0, lift=1.25)]), RelationRecord(items=frozenset({'nCerveja', 'Cafe'}), support=0.3, ordered_statistics=[OrderedStatistic(items_base=frozenset({'Cafe'}), items_add=frozenset({'nCerveja'}), confidence=1.0, lift=1.25)]), RelationRecord(items=frozenset({'nFeijao', 'Cafe'}), support=0.3, ordered_statistics=[OrderedStatistic(items_base=frozenset({'Cafe'}), items_add=frozenset({'nFeijao'}), confidence=1.0, lift=1.25)]), RelationRecord(items=frozenset({'nan', 'Cafe'}), support=0.3, ordered_statistics=[OrderedStatistic(items_base=frozenset({'Cafe'}), items_add=frozenset({'nan'}), confidence=1.0, lift=1.0)]), RelationRecord(items=frozenset({'Pao', 'Manteiga'}), support=0.4, ordered_statistics=[OrderedStatistic(items_base=frozenset({'Manteiga'}), items_add=frozenset({'Pao'}), confidence=0.8, lift=1.6), OrderedStatistic(items_base=frozenset({'Pao'}), items_add=frozenset({'Manteiga'}), confidence=0.8, lift=1.6)]), RelationRecord(items=frozenset({'nArroz', 'Manteiga'}), support=0.5, ordered_statistics=[OrderedStatistic(items_base=frozenset({'Manteiga'}), items_add=frozenset({'nArroz'}), confidence=1.0, lift=1.25)]), RelationRecord(items=frozenset({'nCerveja', 'Manteiga'}), support=0.4, ordered_statistics=[OrderedStatistic(items_base=frozenset({'Manteiga'}), items_add=frozenset({'nCerveja'}), confidence=0.8, lift=1.0)]), RelationRecord(items=frozenset({'nFeijao', 'Manteiga'}), support=0.5, ordered_statistics=[OrderedStatistic(items_base=frozenset({'Manteiga'}), items_add=frozenset({'nFeijao'}), confidence=1.0, lift=1.25)]), RelationRecord(items=frozenset({'nan', 'Manteiga'}), support=0.5, ordered_statistics=[OrderedStatistic(items_base=frozenset({'Manteiga'}), items_add=frozenset({'nan'}), confidence=1.0, lift=1.0)]), RelationRecord(items=frozenset({'nArroz', 'Pao'}), support=0.5, ordered_statistics=[OrderedStatistic(items_base=frozenset({'Pao'}), items_add=frozenset({'nArroz'}), confidence=1.0, lift=1.25)]), RelationRecord(items=frozenset({'nCerveja', 'Pao'}), support=0.4, ordered_statistics=[OrderedStatistic(items_base=frozenset({'Pao'}), items_add=frozenset({'nCerveja'}), confidence=0.8, lift=1.0)]), RelationRecord(items=frozenset({'Pao', 'nFeijao'}), support=0.5, ordered_statistics=[OrderedStatistic(items_base=frozenset({'Pao'}), items_add=frozenset({'nFeijao'}), confidence=1.0, lift=1.25)]), RelationRecord(items=frozenset({'Pao', 'nan'}), support=0.5, ordered_statistics=[OrderedStatistic(items_base=frozenset({'Pao'}), items_add=frozenset({'nan'}), confidence=1.0, lift=1.0)]), RelationRecord(ite ...

# %% [markdown]
# ### Item Sets

# %%
# Para cada item set
for resultado in saida:
    no_null = True
    # Conferir se são todos elementos não nulos
    for elemento in resultado[0]:
        if elemento == 'nan':
            no_null = False
    if no_null:
        itemset_str = "{"
        n_elementos = 0
        # Para cada elemento no item set
        for elemento in resultado[0]:
            # Adicionar elemento ao print
            if n_elementos == 0:
                itemset_str = itemset_str + str(elemento)
            else:
                itemset_str = itemset_str + ", " + str(elemento)
            # Atualizar número de elementos
            n_elementos += 1
        itemset_str = itemset_str + "} "
        # Adicionar número de elementos do item set ao print
        itemset_str = "(" + str(n_elementos) + ") " + itemset_str
        # Adicionar confiança do item set ao print
        itemset_str = itemset_str + " _ " + str(resultado[1])
        print(itemset_str)
# Out:
# (1) {nArroz}  _ 0.8
# (1) {nCerveja}  _ 0.8
# (1) {nFeijao}  _ 0.8
# (1) {nLeite}  _ 0.8
# (2) {Manteiga, Cafe}  _ 0.3
# (2) {Pao, Cafe}  _ 0.3
# (2) {nArroz, Cafe}  _ 0.3
# (2) {nCerveja, Cafe}  _ 0.3
# (2) {nFeijao, Cafe}  _ 0.3
# (2) {Pao, Manteiga}  _ 0.4
# (2) {nArroz, Manteiga}  _ 0.5
# (2) {nCerveja, Manteiga}  _ 0.4
# (2) {nFeijao, Manteiga}  _ 0.5
# (2) {nArroz, Pao}  _ 0.5
# (2) {nCerveja, Pao}  _ 0.4
# (2) {Pao, nFeijao}  _ 0.5
# (2) {nArroz, nFeijao}  _ 0.7
# (2) {nCafe, nLeite}  _ 0.6
# (2) {nCafe, nManteiga}  _ 0.5
# (2) {nPao, nCafe}  _ 0.5
# (2) {nCerveja, nLeite}  _ 0.7
# (2) {nManteiga, nCerveja}  _ 0.4
# (2) {nPao, nCerveja}  _ 0.4
# (2) {nManteiga, nLeite}  _ 0.5
# (2) {nPao, nLeite}  _ 0.5
# (2) {nPao, nManteiga}  _ 0.4
# (3) {Pao, Manteiga, Cafe}  _ 0.3
# (3) {nArroz, Manteiga, Cafe}  _ 0.3
# (3) {nCerveja, Manteiga, Cafe}  _ 0.3
# (3) {nFeijao, Manteiga, Cafe}  _ 0.3
# (3) {nArroz, Pao, Cafe}  _ 0.3
# (3) {nCerveja, Pao, Cafe}  _ 0.3
# (3) {Pao, nFeijao, Cafe}  _ 0.3
# (3) {nArroz, nCerveja, Cafe}  _ 0.3
# (3) {nArroz, nFeijao, Cafe}  _ 0.3
# (3) {nCerveja, nFeijao, Cafe}  _ 0.3
# (3) {nArroz, Pao, Manteiga}  _ 0.4
# (3) {nFeijao, Pao, Manteiga}  _ 0.4
# (3) {nArroz, nCerveja, Manteiga}  _ 0.4
# (3) {nFeijao, nArroz, Manteiga}  _ 0.5
# (3) {nArroz, nLeite, Manteiga}  _ 0.3
# (3) {nFeijao, nCerveja, Manteiga}  _ 0.4
# (3) {nCerveja, Manteiga, nLeite}  _ 0.3
# (3) {nFeijao, nLeite, Manteiga}  _ 0.3
# (3) {nArroz, nCerveja, Pao}  _ 0.4
# (3) {nArroz, Pao, nFeijao}  _ 0.5
# (3) {nArroz, nLeite, Pao}  _ 0.3
# (3) {nCerveja, Pao, nFeijao}  _ 0.4
# (3) {nCerveja, Pao, nLeite}  _ 0.3
# (3) {nLeite, Pao, nFeijao}  _ 0.3
# (3) {nArroz, nCafe, nFeijao}  _ 0.4
# (3) {nArroz, nCafe, nLeite}  _ 0.4
# (3) {nArroz, nCafe, nManteiga}  _ 0.3
# (3) {nPao, nArroz, nCafe}  _ 0.3
# (3) {nArroz, nCerveja, nFeijao}  _ 0.5
# (3) {nArroz, nCerveja, nLeite}  _ 0.5
# (3) {nArroz, nLeite, nFeijao}  _ 0.5
# (3) {nArroz, nManteiga, nLeite}  _ 0.3
# (3) {nPao, nArroz, nLeite}  _ 0.3
# (3) {nCafe, nCerveja, nLeite}  _ 0.5
# (3) {nCafe, nCerveja, nManteiga}  _ 0.4
# (3) {nPao, nCafe, nCerveja}  _ 0.4
# (3) {nCafe, nLeite, nFeijao}  _ 0.4
# (3) {nCafe, nFeijao, nManteiga}  _ 0.3
# (3) {nPao, nCafe, nFeijao}  _ 0.3
# (3) {nCafe, nLeite, nManteiga}  _ 0.5
# (3) {nPao, nCafe, nLeite}  _ 0.5
# (3) {nPao, nCafe, nManteiga}  _ 0.4
# (3) {nCerveja, nFeijao, nLeite}  _ 0.5
# (3) {nManteiga, nCerveja, nLeite}  _ 0.4
# (3) {nPao, nCerveja, nLeite}  _ 0.4
# (3) {nManteiga, nLeite, nFeijao}  _ 0.3
# (3) {nPao, nLeite, nFeijao}  _ 0.3
# (3) {nPao, nManteiga, nLeite}  _ 0.4
# (4) {nArroz, Pao, Manteiga, Cafe}  _ 0.3
# (4) {nCerveja, Pao, Manteiga, Cafe}  _ 0.3
# (4) {nFeijao, Pao, Manteiga, Cafe}  _ 0.3
# (4) {nArroz, nCerveja, Manteiga, Cafe}  _ 0.3
# (4) {nFeijao, nArroz, Manteiga, Cafe}  _ 0.3
# (4) {nFeijao, nCerveja, Manteiga, Cafe}  _ 0.3
# (4) {nArroz, nCerveja, Pao, Cafe}  _ 0.3
# (4) {nArroz, Pao, nFeijao, Cafe}  _ 0.3
# (4) {nCerveja, Pao, nFeijao, Cafe}  _ 0.3
# (4) {nArroz, nCerveja, nFeijao, Cafe}  _ 0.3
# (4) {nArroz, nCerveja, Pao, Manteiga}  _ 0.3
# (4) {nFeijao, nArroz, Pao, Manteiga}  _ 0.4
# (4) {nFeijao, nCerveja, Pao, Manteiga}  _ 0.3
# (4) {nFeijao, nArroz, nCerveja, Manteiga}  _ 0.4
# (4) {nArroz, nCerveja, Manteiga, nLeite}  _ 0.3
# (4) {nFeijao, nArroz, nLeite, Manteiga}  _ 0.3
# (4) {nFeijao, nCerveja, Manteiga, nLeite}  _ 0.3
# (4) {nArroz, nCerveja, Pao, nFeijao}  _ 0.4
# (4) {nArroz, nCerveja, Pao, nLeite}  _ 0.3
# (4) {nArroz, nLeite, Pao, nFeijao}  _ 0.3
# (4) {nCerveja, Pao, nFeijao, nLeite}  _ 0.3
# (4) {nArroz, nCafe, nCerveja, nLeite}  _ 0.3
# (4) {nArroz, nCafe, nLeite, nManteiga}  _ 0.3
# (4) {nPao, nArroz, nCafe, nLeite}  _ 0.3
# (4) {nArroz, nCerveja, nFeijao, nLeite}  _ 0.4
# (4) {nCafe, nCerveja, nFeijao, nLeite}  _ 0.3
# (4) {nCafe, nCerveja, nLeite, nManteiga}  _ 0.4
# (4) {nPao, nCafe, nCerveja, nLeite}  _ 0.4
# (4) {nPao, nCafe, nCerveja, nManteiga}  _ 0.3
# (4) {nCafe, nLeite, nFeijao, nManteiga}  _ 0.3
# (4) {nPao, nCafe, nLeite, nFeijao}  _ 0.3
# (4) {nPao, nCafe, nLeite, nManteiga}  _ 0.4
# (4) {nPao, nManteiga, nCerveja, nLeite}  _ 0.3
# (5) {Pao, nCerveja, Manteiga, nArroz, Cafe}  _ 0.3
# (5) {Pao, Manteiga, nArroz, nFeijao, Cafe}  _ 0.3
# (5) {Pao, nCerveja, Manteiga, nFeijao, Cafe}  _ 0.3
# (5) {nCerveja, Manteiga, nArroz, nFeijao, Cafe}  _ 0.3
# (5) {Pao, nCerveja, nArroz, nFeijao, Cafe}  _ 0.3
# (5) {Pao, nCerveja, Manteiga, nArroz, nFeijao}  _ 0.3
# (5) {nLeite, nCerveja, Manteiga, nArroz, nFeijao}  _ 0.3
# (5) {nLeite, Pao, nCerveja, nArroz, nFeijao}  _ 0.3
# (5) {nLeite, nPao, nCerveja, nCafe, nManteiga}  _ 0.3
# (6) {Pao, nCerveja, Manteiga, nArroz, nFeijao, Cafe}  _ 0.3

# %% [markdown]
# # Transformação em tabela/matriz/dataframe

# %%
# Variáveis de lista de suporte
Antecedente = []; Consequente = []
suporte = []; confianca = []; lift = []
RegrasFinais = []

# Para cada instância em saida
for resultado in saida:
  result_suporte = resultado[1] # Suporte
  result_rules = resultado[2] # Regras possíveis de cada combinação
  # Para cada regra possível
  for result_rule in result_rules:
    result_antecedente = list(result_rule[0]) # Antecedente da regra
    result_consequente = list(result_rule[1]) # Consequente da regra
    result_confianca = result_rule[2] # Confiança da regra
    result_lift = result_rule[3] # Lift da regra

    # Filtrar se algum dos elementos for nulo ou se não houver elementos
    if 'nan' in result_antecedente or 'nan' in result_consequente: continue
    if len(result_antecedente) == 0 or len(result_consequente) == 0: continue

    Antecedente.append(result_antecedente)
    Consequente.append(result_consequente)
    suporte.append(result_suporte)
    confianca.append(result_confianca)
    lift.append(result_lift)

# Montar tabela com os arrays montados
RegrasFinais = pd.DataFrame({'Antecedente': Antecedente, 'Consequente': Consequente, 'suporte': suporte, 'confianca': confianca, 'lift': lift})

# %%
RegrasFinais
# Out:
#                                      Antecedente Consequente  suporte  \
# 0                                         [Cafe]  [Manteiga]      0.3
# 1                                         [Cafe]       [Pao]      0.3
# 2                                         [Cafe]    [nArroz]      0.3
# 3                                         [Cafe]  [nCerveja]      0.3
# 4                                         [Cafe]   [nFeijao]      0.3
# ..                                           ...         ...      ...
# 440       [Pao, Manteiga, nArroz, nFeijao, Cafe]  [nCerveja]      0.3
# 441     [Pao, nCerveja, Manteiga, nFeijao, Cafe]    [nArroz]      0.3
# 442  [nCerveja, Manteiga, nArroz, nFeijao, Cafe]       [Pao]      0.3
# 443       [Pao, nCerveja, nArroz, nFeijao, Cafe]  [Manteiga]      0.3
# 444   [Pao, nCerveja, Manteiga, nArroz, nFeijao]      [Cafe]      0.3
#
#      confianca      lift
# 0          1.0  2.000000
# 1          1.0  2.000000
# 2          1.0  1.250000
# 3          1.0  1.250000
# 4          1.0  1.250000
# ..         ...       ...
# 440        1.0  1.250000
# 441        1.0  1.250000
# 442        1.0  2.000000
# 443        1.0  2.000000
# 444        1.0  3.333333
#
# [445 rows x 5 columns]

# %% [markdown]
# ## Ordenação das regras

# %%
# Ordenação por lft
RegrasFinais.sort_values(by='lift', ascending =False)
# Out:
#                                     Antecedente                Consequente  \
# 444  [Pao, nCerveja, Manteiga, nArroz, nFeijao]                     [Cafe]
# 438          [nFeijao, nCerveja, Pao, Manteiga]             [nArroz, Cafe]
# 437           [nArroz, nCerveja, Pao, Manteiga]            [nFeijao, Cafe]
# 359          [nFeijao, nCerveja, Pao, Manteiga]                     [Cafe]
# 347                             [nFeijao, Cafe]  [nCerveja, Pao, Manteiga]
# ..                                          ...                        ...
# 107                          [nCafe, nManteiga]                 [nCerveja]
# 67                           [nArroz, Manteiga]                 [nCerveja]
# 75                          [nFeijao, Manteiga]                 [nCerveja]
# 11                                        [Pao]                 [nCerveja]
# 8                                    [Manteiga]                 [nCerveja]
#
#      suporte  confianca      lift
# 444      0.3        1.0  3.333333
# 438      0.3        1.0  3.333333
# 437      0.3        1.0  3.333333
# 359      0.3        1.0  3.333333
# 347      0.3        1.0  3.333333
# ..       ...        ...       ...
# 107      0.4        0.8  1.000000
# 67       0.4        0.8  1.000000
# 75       0.4        0.8  1.000000
# 11       0.4        0.8  1.000000
# 8        0.4        0.8  1.000000
#
# [445 rows x 5 columns]

# %% [markdown]
# # Imports

# %%
# Para melhor organização dos dados em tabelas/matrizes
import pandas as pd

# Para mostrar gráficos
import plotly.express as plexp

# %% [markdown]
# # Dados

# %%
# Dados
dados = pd.read_csv('creditcard.csv', sep=',', na_values=["", " ", "NA", "N/A"])
dados

# %% [markdown]
# # Visualizações de Dados

# %%
vis_time = plexp.histogram(dados, x = 'Time')
vis_time.show()

# %%
vis_amount = plexp.histogram(dados, x = 'Amount')
vis_amount.show()

# %%
vis_class = plexp.histogram(dados, x = 'Class')
vis_class.show()

# %%
vis_v1 = plexp.histogram(dados, x = 'V1')
vis_v1.show()

# %%
vis_v2 = plexp.histogram(dados, x = 'V2')
vis_v2.show()

# %%
vis_v3 = plexp.histogram(dados, x = 'V3')
vis_v3.show()

# %%
vis_v4 = plexp.histogram(dados, x = 'V4')
vis_v4.show()

# %%
vis_v5 = plexp.histogram(dados, x = 'V5')
vis_v5.show()

# %%
vis_v6 = plexp.histogram(dados, x = 'V6')
vis_v6.show()

# %%
vis_v7 = plexp.histogram(dados, x = 'V7')
vis_v7.show()

# %%
vis_v8 = plexp.histogram(dados, x = 'V8')
vis_v8.show()

# %%
vis_v9 = plexp.histogram(dados, x = 'V9')
vis_v9.show()

# %%
vis_v10 = plexp.histogram(dados, x = 'V10')
vis_v10.show()

# %%
vis_v11 = plexp.histogram(dados, x = 'V11')
vis_v11.show()

# %%
vis_v12 = plexp.histogram(dados, x = 'V12')
vis_v12.show()

# %%
vis_v13 = plexp.histogram(dados, x = 'V13')
vis_v13.show()

# %%
vis_v14 = plexp.histogram(dados, x = 'V14')
vis_v14.show()

# %%
vis_v15 = plexp.histogram(dados, x = 'V15')
vis_v15.show()

# %%
vis_v16 = plexp.histogram(dados, x = 'V16')
vis_v16.show()

# %%
vis_v17 = plexp.histogram(dados, x = 'V17')
vis_v17.show()

# %%
vis_v18 = plexp.histogram(dados, x = 'V18')
vis_v18.show()

# %%
vis_v19 = plexp.histogram(dados, x = 'V19')
vis_v19.show()

# %%
vis_v20 = plexp.histogram(dados, x = 'V20')
vis_v20.show()

# %%
vis_v21 = plexp.histogram(dados, x = 'V21')
vis_v21.show()

# %%
vis_v22 = plexp.histogram(dados, x = 'V22')
vis_v22.show()

# %%
vis_v23 = plexp.histogram(dados, x = 'V23')
vis_v23.show()

# %%
vis_v24 = plexp.histogram(dados, x = 'V24')
vis_v24.show()

# %%
vis_v25 = plexp.histogram(dados, x = 'V25')
vis_v25.show()

# %%
vis_v26 = plexp.histogram(dados, x = 'V26')
vis_v26.show()

# %%
vis_v27 = plexp.histogram(dados, x = 'V27')
vis_v27.show()

# %%
vis_v28 = plexp.histogram(dados, x = 'V28')
vis_v28.show()

# %% [markdown]
# # Tratamento de Valores Ausentes

# %% [markdown]
# # Detecção e Eliminação de Redundância e Inconsistência

# %% [markdown]
# # Detecção e Tratamento de Outlier

# %% [markdown]
# # Normalização

# %% [markdown]
# # Análise de Correlação e Multicolinearidade

# %% [markdown]
# # Codificação de Variáveis

# %% [markdown]
# # Balanceamento da Classe

# %% [markdown]
# # Divisão Treino–Teste (estratificada)
